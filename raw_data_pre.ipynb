# %%
import os


class Para:
    read_folder_path = 'data/cs_space_20d_rate_20d_2017_raw'
    write_folder_path = 'data/cs_space_20d_rate_20d_2017_pre'
    month_num = len(os.listdir(read_folder_path))
para = Para()
print(para.month_num)
# Out:
# 60

# %%
import time
import numpy as np
import pandas as pd


time_begin = time.time()
# 数据预处理
for i_csv in range(para.month_num):
    df = pd.read_csv(para.read_folder_path +'/'+ str(i_csv) + '.csv', index_col='order_book_id')

    df['date'] = pd.to_datetime(df['date'])

    # Replace infinite updated data with nan
    df.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

    # 剔除含有 na 的行
    df_dropna = df.dropna(axis=0, how='any')

    # 选择特征列和标签列
    df_dropna_y = df_dropna[['board_type', 'sector_code', 'month', 'date']]
    df_dropna_features = df_dropna.loc[:, 'ep_ratio_ttm':'BR']
    df_dropna_features = pd.concat([df_dropna['yield_rate'], df_dropna_features], axis=1)

    # 中位数去极值
    df_dropna_features = df_dropna_features.clip(
        lower=df_dropna_features.median(axis=0) - 5 * df_dropna_features.mad(axis=0),
        upper=df_dropna_features.median(axis=0) + 5 * df_dropna_features.mad(axis=0),
        axis=1)

    # 标准化
    df_dropna_features = (df_dropna_features - df_dropna_features.mean()) / df_dropna_features.std(ddof=0)

    # 拼接标签列和特征列
    df_dropna_standard = pd.concat([df_dropna_y, df_dropna_features], axis=1)

    # Replace infinite updated data with nan
    df_dropna_standard.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

    # 剔除含有 na 的行
    df_dropna_standard = df_dropna_standard.dropna(axis=0, how='any')

    # 写入文件
    df_dropna_standard.to_csv(para.write_folder_path + '/' + str(i_csv) + '.csv')

    print()
    print('i_csv: {}'.format(i_csv))
    print('use time: {}'.format(time.time() - time_begin))

print()
print('Done!')
# Out:
# i_csv: 0
# use time: 0.22151422500610352
#
# i_csv: 1
# use time: 0.39252209663391113
#
# i_csv: 2
# use time: 0.5856823921203613
#
# i_csv: 3
# use time: 0.8186168670654297
#
# i_csv: 4
# use time: 1.0100862979888916
#
# i_csv: 5
# use time: 1.2616446018218994
#
# i_csv: 6
# use time: 1.4929697513580322
#
# i_csv: 7
# use time: 1.7902100086212158
#
# i_csv: 8
# use time: 1.9915211200714111
#
# i_csv: 9
# use time: 2.235684394836426
#
# i_csv: 10
# use time: 2.4881794452667236
#
# i_csv: 11
# use time: 2.765219211578369
#
# i_csv: 12
# use time: 3.0276529788970947
#
# i_csv: 13
# use time: 3.2290375232696533
#
# i_csv: 14
# use time: 3.4404547214508057
#
# i_csv: 15
# use time: 3.6927192211151123
#
# i_csv: 16
# use time: 3.978452205657959
#
# i_csv: 17
# use time: 4.230835676193237
#
# i_csv: 18
# use time: 4.463052272796631
#
# i_csv: 19
# use time: 4.735838174819946
#
# i_csv: 20
# use time: 5.028495788574219
#
# i_csv: 21
# use time: 5.261080741882324
#
# i_csv: 22
# use time: 5.533146142959595
#
# i_csv: 23
# use time: 5.809209823608398
#
# i_csv: 24
# use time: 6.103108167648315
#
# i_csv: 25
# use time: 6.394904851913452
#
# i_csv: 26
# use time: 6.667320489883423
#
# i_csv: 27
# use time: 7.0501813888549805
#
# i_csv: 28
# use time: 7.362945556640625
#
# i_csv: 29
# use time: 7.58440375328064
#
# i_csv: 30
# use time: 7.82617712020874
#
# i_csv: 31
# use time: 8.150401830673218
#
# i_csv: 32
# use time: 8.47252082824707
#
# i_csv: 33
# use time: 8.77861499786377
#
# i_csv: 34
# use time: 9.030769109725952
#
# i_csv: 35
# use time: 9.40987229347229
#
# i_csv: 36
# use time: 9.692265748977661
#
# i_csv: 37
# use time: 9.934060335159302
#
# i_csv: 38
# use time: 10.155532836914062
#
# i_csv: 39
# use time: 10.526819944381714
#
# i_csv: 40
# use time: 10.907651662826538
#
# i_csv: 41
# use time: 11.223334789276123
#
# i_csv: 42
# use time: 11.609193325042725
#
# i_csv: 43
# use time: 11.94233250617981
#
# i_csv: 44
# use time: 12.245017290115356
#
# i_csv: 45
# use time: 12.569990158081055
#
# i_csv: 46
# use time: 12.884393215179443
#
# i_csv: 47
# use time: 13.25461745262146
#
# i_csv: 48
# use time: 13.642569780349731
#
# i_csv: 49
# use time: 14.52160358428955
#
# i_csv: 50
# use time: 14.94727087020874
#
# i_csv: 51
# use time: 15.28125548362732
#
# i_csv: 52
# use time: 15.594104051589966
#
# i_csv: 53
# use time: 15.979849815368652
#
# i_csv: 54
# use time: 16.333513736724854
#
# i_csv: 55
# use time: 16.83449077606201
#
# i_csv: 56
# use time: 17.13426947593689
#
# i_csv: 57
# use time: 17.82814335823059
#
# i_csv: 58
# use time: 18.171201705932617
#
# i_csv: 59
# use time: 18.48411202430725
#
# Done!
