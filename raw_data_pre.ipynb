# %%
import os


class Para:
    read_folder_path = 'data/cs_space_5d_rate_5d_2017_tech_raw'
    write_folder_path = 'data/cs_space_5d_rate_5d_2017_tech_pre'

    feature_column_start_name = 'VOL5'
    feature_column_end_name = 'AROON_DOWN'

    month_num = len(os.listdir(read_folder_path))
para = Para()
print(para.month_num)
# Out:
# 243

# %%
import time
import numpy as np
import pandas as pd


time_begin = time.time()
# 数据预处理
for i_csv in range(para.month_num):
    df = pd.read_csv(para.read_folder_path +'/'+ str(i_csv) + '.csv', index_col='order_book_id')

    df['date'] = pd.to_datetime(df['date'])

    # Replace infinite updated data with nan
    df.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

    # 剔除含有 na 的行
    df_dropna = df.dropna(axis=0, how='any')

    # 选择特征列和标签列
    df_dropna_y = df_dropna[['board_type', 'sector_code', 'month', 'date']]
    df_dropna_features = df_dropna.loc[:, para.feature_column_start_name:para.feature_column_end_name]
    df_dropna_features = pd.concat([df_dropna['yield_rate'], df_dropna_features], axis=1)

    # 中位数去极值
    df_dropna_features = df_dropna_features.clip(
        lower=df_dropna_features.median(axis=0) - 5 * df_dropna_features.mad(axis=0),
        upper=df_dropna_features.median(axis=0) + 5 * df_dropna_features.mad(axis=0),
        axis=1)

    # 标准化
    df_dropna_features = (df_dropna_features - df_dropna_features.mean()) / df_dropna_features.std(ddof=0)

    # 拼接标签列和特征列
    df_dropna_standard = pd.concat([df_dropna_y, df_dropna_features], axis=1)

    # Replace infinite updated data with nan
    df_dropna_standard.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

    # 剔除含有 na 的行
    df_dropna_standard = df_dropna_standard.dropna(axis=0, how='any')

    # 写入文件
    df_dropna_standard.to_csv(para.write_folder_path + '/' + str(i_csv) + '.csv')

    print()
    print('i_csv: {}'.format(i_csv))
    print('use time: {}'.format(time.time() - time_begin))

print()
print('Done!')
# Out:
# i_csv: 0
# use time: 0.26018643379211426
#
# i_csv: 1
# use time: 0.46164846420288086
#
# i_csv: 2
# use time: 0.6571276187896729
#
# i_csv: 3
# use time: 0.8552253246307373
#
# i_csv: 4
# use time: 1.0533385276794434
#
# i_csv: 5
# use time: 1.215543270111084
#
# i_csv: 6
# use time: 1.3850882053375244
#
# i_csv: 7
# use time: 1.547654628753662
#
# i_csv: 8
# use time: 1.7158539295196533
#
# i_csv: 9
# use time: 1.9203004837036133
#
# i_csv: 10
# use time: 2.143977403640747
#
# i_csv: 11
# use time: 2.322500467300415
#
# i_csv: 12
# use time: 2.5070064067840576
#
# i_csv: 13
# use time: 2.7053120136260986
#
# i_csv: 14
# use time: 2.906771659851074
#
# i_csv: 15
# use time: 3.1307244300842285
#
# i_csv: 16
# use time: 3.3010568618774414
#
# i_csv: 17
# use time: 3.4656167030334473
#
# i_csv: 18
# use time: 3.655113458633423
#
# i_csv: 19
# use time: 3.8363001346588135
#
# i_csv: 20
# use time: 4.008837699890137
#
# i_csv: 21
# use time: 4.204517364501953
#
# i_csv: 22
# use time: 4.402985572814941
#
# i_csv: 23
# use time: 4.578514814376831
#
# i_csv: 24
# use time: 4.762843370437622
#
# i_csv: 25
# use time: 4.983255863189697
#
# i_csv: 26
# use time: 5.213345766067505
#
# i_csv: 27
# use time: 5.396854877471924
#
# i_csv: 28
# use time: 5.572384834289551
#
# i_csv: 29
# use time: 5.789960861206055
#
# i_csv: 30
# use time: 6.023014545440674
#
# i_csv: 31
# use time: 6.200093507766724
#
# i_csv: 32
# use time: 6.390582323074341
#
# i_csv: 33
# use time: 6.596033573150635
#
# i_csv: 34
# use time: 6.801105737686157
#
# i_csv: 35
# use time: 7.0045599937438965
#
# i_csv: 36
# use time: 7.203970670700073
#
# i_csv: 37
# use time: 7.427373647689819
#
# i_csv: 38
# use time: 7.6009087562561035
#
# i_csv: 39
# use time: 7.807549476623535
#
# i_csv: 40
# use time: 8.080052614212036
#
# i_csv: 41
# use time: 8.293073892593384
#
# i_csv: 42
# use time: 8.490546703338623
#
# i_csv: 43
# use time: 8.684030055999756
#
# i_csv: 44
# use time: 8.925987005233765
#
# i_csv: 45
# use time: 9.154387474060059
#
# i_csv: 46
# use time: 9.370609045028687
#
# i_csv: 47
# use time: 9.591532945632935
#
# i_csv: 48
# use time: 9.856296062469482
#
# i_csv: 49
# use time: 10.084572315216064
#
# i_csv: 50
# use time: 10.264752388000488
#
# i_csv: 51
# use time: 10.537025213241577
#
# i_csv: 52
# use time: 10.815883874893188
#
# i_csv: 53
# use time: 11.03494930267334
#
# i_csv: 54
# use time: 11.240940570831299
#
# i_csv: 55
# use time: 11.433425664901733
#
# i_csv: 56
# use time: 11.626907587051392
#
# i_csv: 57
# use time: 11.893848657608032
#
# i_csv: 58
# use time: 12.14113712310791
#
# i_csv: 59
# use time: 12.342536687850952
#
# i_csv: 60
# use time: 12.525052309036255
#
# i_csv: 61
# use time: 12.729133367538452
#
# i_csv: 62
# use time: 12.976473331451416
#
# i_csv: 63
# use time: 13.173128843307495
#
# i_csv: 64
# use time: 13.378581523895264
#
# i_csv: 65
# use time: 13.597995519638062
#
# i_csv: 66
# use time: 13.808066606521606
#
# i_csv: 67
# use time: 14.00256633758545
#
# i_csv: 68
# use time: 14.195323467254639
#
# i_csv: 69
# use time: 14.424707412719727
#
# i_csv: 70
# use time: 14.61819052696228
#
# i_csv: 71
# use time: 14.844393491744995
#
# i_csv: 72
# use time: 15.074479818344116
#
# i_csv: 73
# use time: 15.262662172317505
#
# i_csv: 74
# use time: 15.441181182861328
#
# i_csv: 75
# use time: 15.705057382583618
#
# i_csv: 76
# use time: 15.927462339401245
#
# i_csv: 77
# use time: 16.139140844345093
#
# i_csv: 78
# use time: 16.32265043258667
#
# i_csv: 79
# use time: 16.5330867767334
#
# i_csv: 80
# use time: 16.789031267166138
#
# i_csv: 81
# use time: 16.999467849731445
#
# i_csv: 82
# use time: 17.20827627182007
#
# i_csv: 83
# use time: 17.42669177055359
#
# i_csv: 84
# use time: 17.634727716445923
#
# i_csv: 85
# use time: 17.844775199890137
#
# i_csv: 86
# use time: 18.0807683467865
#
# i_csv: 87
# use time: 18.30283498764038
#
# i_csv: 88
# use time: 18.515268564224243
#
# i_csv: 89
# use time: 18.711339712142944
#
# i_csv: 90
# use time: 18.931726455688477
#
# i_csv: 91
# use time: 19.14154553413391
#
# i_csv: 92
# use time: 19.346486806869507
#
# i_csv: 93
# use time: 19.565901041030884
#
# i_csv: 94
# use time: 19.773009538650513
#
# i_csv: 95
# use time: 19.99357318878174
#
# i_csv: 96
# use time: 20.258639097213745
#
# i_csv: 97
# use time: 20.53390145301819
#
# i_csv: 98
# use time: 20.802088737487793
#
# i_csv: 99
# use time: 21.08624839782715
#
# i_csv: 100
# use time: 21.403091192245483
#
# i_csv: 101
# use time: 21.64643955230713
#
# i_csv: 102
# use time: 21.940760612487793
#
# i_csv: 103
# use time: 22.273308992385864
#
# i_csv: 104
# use time: 22.571510314941406
#
# i_csv: 105
# use time: 22.906744718551636
#
# i_csv: 106
# use time: 23.277092218399048
#
# i_csv: 107
# use time: 23.517448663711548
#
# i_csv: 108
# use time: 24.225574493408203
#
# i_csv: 109
# use time: 24.414073705673218
#
# i_csv: 110
# use time: 24.62251615524292
#
# i_csv: 111
# use time: 24.86123013496399
#
# i_csv: 112
# use time: 25.075273513793945
#
# i_csv: 113
# use time: 25.27669095993042
#
# i_csv: 114
# use time: 25.49510669708252
#
# i_csv: 115
# use time: 25.8099844455719
#
# i_csv: 116
# use time: 26.06831669807434
#
# i_csv: 117
# use time: 26.276411771774292
#
# i_csv: 118
# use time: 26.47488307952881
#
# i_csv: 119
# use time: 26.686314821243286
#
# i_csv: 120
# use time: 26.896345853805542
#
# i_csv: 121
# use time: 27.10634160041809
#
# i_csv: 122
# use time: 27.343546390533447
#
# i_csv: 123
# use time: 27.542014598846436
#
# i_csv: 124
# use time: 27.756059408187866
#
# i_csv: 125
# use time: 27.98045825958252
#
# i_csv: 126
# use time: 28.188226461410522
#
# i_csv: 127
# use time: 28.37785029411316
#
# i_csv: 128
# use time: 28.585739135742188
#
# i_csv: 129
# use time: 28.811854600906372
#
# i_csv: 130
# use time: 29.019957065582275
#
# i_csv: 131
# use time: 29.225028038024902
#
# i_csv: 132
# use time: 29.40853786468506
#
# i_csv: 133
# use time: 29.620970249176025
#
# i_csv: 134
# use time: 29.919817686080933
#
# i_csv: 135
# use time: 30.181696891784668
#
# i_csv: 136
# use time: 30.388141870498657
#
# i_csv: 137
# use time: 30.579652547836304
#
# i_csv: 138
# use time: 30.790776014328003
#
# i_csv: 139
# use time: 31.029768705368042
#
# i_csv: 140
# use time: 31.227854013442993
#
# i_csv: 141
# use time: 31.445271968841553
#
# i_csv: 142
# use time: 31.66818642616272
#
# i_csv: 143
# use time: 31.9014413356781
#
# i_csv: 144
# use time: 32.14844584465027
#
# i_csv: 145
# use time: 32.37648892402649
#
# i_csv: 146
# use time: 32.57894968986511
#
# i_csv: 147
# use time: 32.78696393966675
#
# i_csv: 148
# use time: 32.989421367645264
#
# i_csv: 149
# use time: 33.22705292701721
#
# i_csv: 150
# use time: 33.42951154708862
#
# i_csv: 151
# use time: 33.62208604812622
#
# i_csv: 152
# use time: 33.865989208221436
#
# i_csv: 153
# use time: 34.083210945129395
#
# i_csv: 154
# use time: 34.28374910354614
#
# i_csv: 155
# use time: 34.507161378860474
#
# i_csv: 156
# use time: 34.72598671913147
#
# i_csv: 157
# use time: 34.95225286483765
#
# i_csv: 158
# use time: 35.17187976837158
#
# i_csv: 159
# use time: 35.38491344451904
#
# i_csv: 160
# use time: 35.57043099403381
#
# i_csv: 161
# use time: 35.765135288238525
#
# i_csv: 162
# use time: 36.01615619659424
#
# i_csv: 163
# use time: 36.22127628326416
#
# i_csv: 164
# use time: 36.423733711242676
#
# i_csv: 165
# use time: 36.61422157287598
#
# i_csv: 166
# use time: 36.83356690406799
#
# i_csv: 167
# use time: 37.04658818244934
#
# i_csv: 168
# use time: 37.24476337432861
#
# i_csv: 169
# use time: 37.476141929626465
#
# i_csv: 170
# use time: 37.53698015213013
#
# i_csv: 171
# use time: 37.74605751037598
#
# i_csv: 172
# use time: 37.958489179611206
#
# i_csv: 173
# use time: 38.19117283821106
#
# i_csv: 174
# use time: 38.39263367652893
#
# i_csv: 175
# use time: 38.606061935424805
#
# i_csv: 176
# use time: 38.82865929603577
#
# i_csv: 177
# use time: 39.06181073188782
#
# i_csv: 178
# use time: 39.26192808151245
#
# i_csv: 179
# use time: 39.4653844833374
#
# i_csv: 180
# use time: 39.68978667259216
#
# i_csv: 181
# use time: 39.90052151679993
#
# i_csv: 182
# use time: 40.142335414886475
#
# i_csv: 183
# use time: 40.39355969429016
#
# i_csv: 184
# use time: 40.62094569206238
#
# i_csv: 185
# use time: 40.841004848480225
#
# i_csv: 186
# use time: 41.08322739601135
#
# i_csv: 187
# use time: 41.29828667640686
#
# i_csv: 188
# use time: 41.50174283981323
#
# i_csv: 189
# use time: 41.742735147476196
#
# i_csv: 190
# use time: 41.97212195396423
#
# i_csv: 191
# use time: 42.198867082595825
#
# i_csv: 192
# use time: 42.40372133255005
#
# i_csv: 193
# use time: 42.62315583229065
#
# i_csv: 194
# use time: 42.867148637771606
#
# i_csv: 195
# use time: 43.09815192222595
#
# i_csv: 196
# use time: 43.352107524871826
#
# i_csv: 197
# use time: 43.55458879470825
#
# i_csv: 198
# use time: 43.7928946018219
#
# i_csv: 199
# use time: 44.03003787994385
#
# i_csv: 200
# use time: 44.23014450073242
#
# i_csv: 201
# use time: 45.02225136756897
#
# i_csv: 202
# use time: 45.24256706237793
#
# i_csv: 203
# use time: 45.45799231529236
#
# i_csv: 204
# use time: 45.67042279243469
#
# i_csv: 205
# use time: 45.898489236831665
#
# i_csv: 206
# use time: 46.14150071144104
#
# i_csv: 207
# use time: 46.37188792228699
#
# i_csv: 208
# use time: 46.583319902420044
#
# i_csv: 209
# use time: 46.81429958343506
#
# i_csv: 210
# use time: 47.06035804748535
#
# i_csv: 211
# use time: 47.27141499519348
#
# i_csv: 212
# use time: 47.48484516143799
#
# i_csv: 213
# use time: 47.716931104660034
#
# i_csv: 214
# use time: 47.95828557014465
#
# i_csv: 215
# use time: 48.1800971031189
#
# i_csv: 216
# use time: 48.42845439910889
#
# i_csv: 217
# use time: 48.647844314575195
#
# i_csv: 218
# use time: 48.89879631996155
#
# i_csv: 219
# use time: 49.1718864440918
#
# i_csv: 220
# use time: 49.416231870651245
#
# i_csv: 221
# use time: 49.64761519432068
#
# i_csv: 222
# use time: 49.92548704147339
#
# i_csv: 223
# use time: 50.17163443565369
#
# i_csv: 224
# use time: 50.40601110458374
#
# i_csv: 225
# use time: 50.641379594802856
#
# i_csv: 226
# use time: 50.88138175010681
#
# i_csv: 227
# use time: 51.11544728279114
#
# i_csv: 228
# use time: 51.34268856048584
#
# i_csv: 229
# use time: 51.583045959472656
#
# i_csv: 230
# use time: 51.82005739212036
#
# i_csv: 231
# use time: 52.07411432266235
#
# i_csv: 232
# use time: 52.34404969215393
#
# i_csv: 233
# use time: 52.601365089416504
#
# i_csv: 234
# use time: 52.84433627128601
#
# i_csv: 235
# use time: 53.085286378860474
#
# i_csv: 236
# use time: 53.34739446640015
#
# i_csv: 237
# use time: 53.57877779006958
#
# i_csv: 238
# use time: 53.83506536483765
#
# i_csv: 239
# use time: 54.10405206680298
#
# i_csv: 240
# use time: 54.330771923065186
#
# i_csv: 241
# use time: 54.55218029022217
#
# i_csv: 242
# use time: 54.79513216018677
#
# Done!
