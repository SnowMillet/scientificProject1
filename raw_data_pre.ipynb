# %%
import os


class Para:
    read_folder_path = 'data/cs_space_1d_rate_5d_2022_tech_raw'
    write_folder_path = 'data/cs_space_1d_rate_5d_2022_tech_pre'

    feature_column_start_name = 'VOL5'
    feature_column_end_name = 'AROON_DOWN'

    month_num = len(os.listdir(read_folder_path))
para = Para()
print(para.month_num)
# Out:
# 46

# %%
import time
import numpy as np
import pandas as pd


time_begin = time.time()
# 数据预处理
for i_csv in range(para.month_num):
    df = pd.read_csv(para.read_folder_path +'/'+ str(i_csv) + '.csv', index_col='order_book_id')

    df['date'] = pd.to_datetime(df['date'])

    # Replace infinite updated data with nan
    df.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

    # 剔除含有 na 的行
    df_dropna = df.dropna(axis=0, how='any')

    # 选择特征列和标签列
    df_dropna_y = df_dropna[['board_type', 'sector_code', 'month', 'date']]
    df_dropna_features = df_dropna.loc[:, para.feature_column_start_name:para.feature_column_end_name]
    df_dropna_features = pd.concat([df_dropna['yield_rate'], df_dropna_features], axis=1)

    # 中位数去极值
    df_dropna_features = df_dropna_features.clip(
        lower=df_dropna_features.median(axis=0) - 5 * df_dropna_features.mad(axis=0),
        upper=df_dropna_features.median(axis=0) + 5 * df_dropna_features.mad(axis=0),
        axis=1)

    # 标准化
    df_dropna_features = (df_dropna_features - df_dropna_features.mean()) / df_dropna_features.std(ddof=0)

    # 拼接标签列和特征列
    df_dropna_standard = pd.concat([df_dropna_y, df_dropna_features], axis=1)

    # Replace infinite updated data with nan
    df_dropna_standard.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

    # 剔除含有 na 的行
    df_dropna_standard = df_dropna_standard.dropna(axis=0, how='any')

    # 写入文件
    df_dropna_standard.to_csv(para.write_folder_path + '/' + str(i_csv) + '.csv')

    print()
    print('i_csv: {}'.format(i_csv))
    print('use time: {}'.format(time.time() - time_begin))

print()
print('Done!')
# Out:
# i_csv: 0
# use time: 0.31612563133239746
#
# i_csv: 1
# use time: 0.6362700462341309
#
# i_csv: 2
# use time: 0.9166760444641113
#
# i_csv: 3
# use time: 1.2095537185668945
#
# i_csv: 4
# use time: 1.4798316955566406
#
# i_csv: 5
# use time: 1.7595932483673096
#
# i_csv: 6
# use time: 2.0161759853363037
#
# i_csv: 7
# use time: 2.333324670791626
#
# i_csv: 8
# use time: 2.614316940307617
#
# i_csv: 9
# use time: 2.9051225185394287
#
# i_csv: 10
# use time: 3.232379913330078
#
# i_csv: 11
# use time: 3.520608901977539
#
# i_csv: 12
# use time: 3.7785685062408447
#
# i_csv: 13
# use time: 4.033473491668701
#
# i_csv: 14
# use time: 4.287769317626953
#
# i_csv: 15
# use time: 4.510178804397583
#
# i_csv: 16
# use time: 4.728790283203125
#
# i_csv: 17
# use time: 4.978734731674194
#
# i_csv: 18
# use time: 5.2257139682769775
#
# i_csv: 19
# use time: 5.474052667617798
#
# i_csv: 20
# use time: 5.7572925090789795
#
# i_csv: 21
# use time: 6.05670428276062
#
# i_csv: 22
# use time: 6.36288595199585
#
# i_csv: 23
# use time: 6.615210771560669
#
# i_csv: 24
# use time: 6.879875898361206
#
# i_csv: 25
# use time: 7.180724143981934
#
# i_csv: 26
# use time: 7.427042722702026
#
# i_csv: 27
# use time: 7.667398929595947
#
# i_csv: 28
# use time: 7.919118642807007
#
# i_csv: 29
# use time: 8.168898820877075
#
# i_csv: 30
# use time: 8.431196928024292
#
# i_csv: 31
# use time: 8.676541566848755
#
# i_csv: 32
# use time: 8.919441938400269
#
# i_csv: 33
# use time: 9.145431756973267
#
# i_csv: 34
# use time: 9.390804052352905
#
# i_csv: 35
# use time: 9.62418246269226
#
# i_csv: 36
# use time: 9.868118524551392
#
# i_csv: 37
# use time: 10.114055633544922
#
# i_csv: 38
# use time: 10.360397338867188
#
# i_csv: 39
# use time: 10.602750062942505
#
# i_csv: 40
# use time: 10.819071769714355
#
# i_csv: 41
# use time: 11.066087484359741
#
# i_csv: 42
# use time: 11.305447578430176
#
# i_csv: 43
# use time: 11.542811393737793
#
# i_csv: 44
# use time: 11.767211437225342
#
# i_csv: 45
# use time: 12.003851413726807
#
# Done!
